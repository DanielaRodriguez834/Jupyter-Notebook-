# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio #

# %% [markdown]
# **Daniela Rodriguez**
#
# Aspiring Data Scientist

# %% [markdown]
# *I am Interested in data science because I want to change careers and focus on something I really enjoy*

# %% [markdown]
# ### This code will show how to multiple numbers in python ###

# %%
# we want to mutiply real numbers 
# we define our variables

x = 89
y = 8465

#we excecute the code

multiplication = x*y

#we print the result 
print ("the multiplication of x times y is", multiplication)
# Out:
# the multiplication of x times y is 753385

# %% [markdown]
# Learning Data Science
# ---
# - Interesting
# - Hands on practice
# - Ready for new job
# 1. ![Data+Science.png](attachment:Data+Science.png)
